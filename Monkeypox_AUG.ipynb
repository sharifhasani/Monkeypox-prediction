# %% [markdown]
# # import libraries

# %%
from glob import glob
import cv2
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from keras.applications.densenet import DenseNet169
from tensorflow.keras.applications import VGG16, VGG19, EfficientNetB4
from sklearn.model_selection import cross_validate, KFold
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score,\
    confusion_matrix, f1_score, precision_score, recall_score, roc_curve, auc
from google.colab import drive

# %% [markdown]
# # Get Dataset

# %% [markdown]
# Download dataset first time and save to google drive

# %%
# drive.mount('/content/drive')
# ! wget -P /content/drive/MyDrive https://github.com/muhammedtalo/COVID-19/archive/refs/heads/master.zip
# ! unzip -q "/content/drive/MyDrive/Source/DeepLearning/Monkeypox /Dataset/Monkeypox-Dataset.zip" -d "/content/drive/MyDrive/Source/DeepLearning/Monkeypox /Dataset/Extract"

# %% [markdown]
# run this cell when dataset exist in google drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Data

# %% [markdown]
# load images directory

# %%
images_path = {}
images_path["MonkeyPox"] = glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Monkeypox_augmented/*.png")
images_path["MonkeyPox"] += glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Monkeypox_augmented/*.jpeg")
images_path["MonkeyPox"] += glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Monkeypox_augmented/*.jpg")

images_path["Others"] = glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Others_augmented/*.png")
images_path["Others"] += glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Others_augmented/*.jpeg")
images_path["Others"] += glob(
    "/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract"\
    "/Augmented Images/Augmented Images/Others_augmented/*.jpg")


print(images_path["MonkeyPox"])
print(images_path["Others"])


images_class = {
    "MonkeyPox": 0,
    "Others": 1,
}
# Out:
# ['/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M50_03_04.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M42_01_00.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M48_02_07.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M53_01_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M28_01_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M39_01_05.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M48_02_11.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M18_01_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M26_01_11.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M21_01_01.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M28_01_11.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M34_03_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M45_01_11.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M28_03_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M28_02_04.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M15_01_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M25_02_06.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M48_03_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M18_01_07.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M53_01_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M36_01_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M36_01_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M40_02_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M51_01_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M32_01_07.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M34_03_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M34_02_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Monkeypox_augmented/M31_02_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented ...
# ['/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM43_04_06.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM43_03_07.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM49_01_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM56_01_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM46_01_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM43_03_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM37_01_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM98_02_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM83_01_13.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM77_01_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM22_01_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM41_01_04.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM25_01_00.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM58_02_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM49_01_05.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM44_01_11.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM96_01_10.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM33_02_12.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM33_02_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM27_01_00.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM65_01_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM84_01_02.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM58_01_09.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM20_01_00.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM54_01_12.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM91_01_13.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM47_02_08.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM98_01_03.jpg', '/content/drive/MyDrive/Source/DeepLearning/Monkeypox/Dataset/Extract/Augmented Images/Augmented Images/Others_augmented/NM94_01_12.jpg ...

# %%
X = []
Y = []

for label in images_path:
    for image_path in images_path[label]:
        image = cv2.imread(image_path)
        image = cv2.resize(image,(224, 224))
        X.append(image)
        Y.append(images_class[label])

plt.imshow(X[0])
plt.show()

# %%
print(np.array(X).shape)
print(np.array(Y).shape)
plt.imshow(X[100])
# Out:
# (3192, 224, 224, 3)
# (3192,)

# %% [markdown]
# # Build model

# %% [markdown]
# build model and get features

# %%
x = np.array(X)
y = np.array(Y)

# initial pre trained model
pre_trained_models = {}
pre_trained_models["VGG19"] = EfficientNetB4(include_top=False,
                                             input_shape=(224, 224, 3),
                                             pooling="avg")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 1s 0us/step

# %% [markdown]
# # Split train and test data

# %% [markdown]
# slpit and make flatten features

# %%
features = pre_trained_models["VGG19"].predict(x)
X_train, X_test, Y_train, Y_test = train_test_split(features, y,
                                                    test_size=0.2,
                                                    random_state=934)
# Out:
# 100/100 [==============================] - 650s 6s/step

# %% [markdown]
# # Classification

# %% [markdown]
# initial XGBoost classifier

# %%
result = {}

XGB_Classifier = XGBClassifier(learning_rate=0.36, n_estimator=500)

# %% [markdown]
# fit XGBoost classifier

# %%
XGB_Classifier.fit(X_train, Y_train)

Y_pred = XGB_Classifier.predict(X_test)

# %% [markdown]
# print result

# %%
result["Accuracy score"] = accuracy_score(Y_test, Y_pred)
result["confusion matrix"] = confusion_matrix(Y_test, Y_pred)
result["f1 score"] = f1_score(Y_test, Y_pred, average="macro")
result["precision score"] = precision_score(Y_test, Y_pred, average="macro")
result["Sensitivity"] = result["confusion matrix"][0,0] / (result["confusion matrix"][0,0] + result["confusion matrix"][0,1])
result["Specifity"] = result["confusion matrix"][1,1] / (result["confusion matrix"][1,0] + result["confusion matrix"][1,1])

print(f"\n============")
print(f"\nAccuracy score : ", result["Accuracy score"])
print(f"\nconfusion matrix : \n", result["confusion matrix"])
print(f"\nf1 score : ", result["f1 score"])
print(f"\nprecision score : ", result["precision score"])
print(f"\nSpecifity : ", result["Specifity"])
print(f"\nSensitivity : ", result["Sensitivity"])
# Out:
# ============
#
# Accuracy score :  0.9358372456964006
#
# confusion matrix :
#  [[268  24]
#  [ 17 330]]
#
# f1 score :  0.9352274665803001
#
# precision score :  0.9362771335117455
#
# Specifity :  0.9510086455331412
#
# Sensitivity :  0.9178082191780822
